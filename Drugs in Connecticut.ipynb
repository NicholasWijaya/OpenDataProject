# %% [markdown]
# # Accidental Drug-related Deaths in Connecticut

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# Display 2012-2018 accident records:

# %%
filepath_1 = "D:\\CODE1161\\OpenDataProject\\accidents.csv"
accident_records = pd.read_csv(filepath_1)
accident_records.head()
# Out:
#         ID         Date      DateType   Age     Sex          Race  \
# 0  14-0273   06/28/2014  DateReported   NaN     NaN           NaN
# 1  13-0102  03/21/2013    DateofDeath  48.0    Male         Black
# 2  16-0165  03/13/2016    DateofDeath  30.0  Female         White
# 3  16-0208  03/31/2016    DateofDeath  23.0    Male         White
# 4  13-0052  02/13/2013    DateofDeath  22.0    Male  Asian, Other
#
#   ResidenceCity ResidenceCounty ResidenceState  DeathCity  ... Tramad  \
# 0           NaN             NaN            NaN        NaN  ...    NaN
# 1       NORWALK             NaN            NaN    NORWALK  ...    NaN
# 2    SANDY HOOK       FAIRFIELD             CT    DANBURY  ...    NaN
# 3           RYE     WESTCHESTER             NY  GREENWICH  ...    NaN
# 4      FLUSHING          QUEENS            NaN  GREENWICH  ...    NaN
#
#   Morphine_NotHeroin Hydromorphone Other OpiateNOS AnyOpioid MannerofDeath  \
# ...

# %% [markdown]
# Display 2012-2018 drug-related deaths per county:

# %%
filepath_2 = "D:\\CODE1161\\OpenDataProject\\countyData.csv"
county_data = pd.read_csv(filepath_2)
county_data.head()
# Out:
#        County  Year State  County FIPS Code  Population  \
# 0   FAIRFIELD  2018    CT              9001      943823
# 1    HARTFORD  2018    CT              9003      892697
# 2  LITCHFIELD  2018    CT              9005      181111
# 3   MIDDLESEX  2018    CT              9007      162682
# 4   NEW HAVEN  2018    CT              9009      857620
#
#    Opioid Prescribed per 100  Total Deaths  Crude Rate per 100,000  \
# 0                       33.8          6859                   726.7
# 1                       43.3          8239                   922.9
# 2                       47.0          1904                  1051.3
# 3                       49.6          1620                   995.8
# 4                       48.6          7933                   925.0
#
#    Age Adjusted Rate per 100,000  Drug-related Deaths   \
# 0                          552.1                   189
# 1                          674.4                   313
# ...

# %% [markdown]
# Let's compare the deaths by County year-to-year:

# %%
county_names = list(county_data.County.unique())

with plt.style.context("dark_background"):
    for name in county_names:
        # check with prescription rate and drug-related deaths
        total_death_annual = county_data[["Year", "Total Deaths"]][county_data["County"] == name]
        plt.plot(total_death_annual,"x-")
plt.show()
